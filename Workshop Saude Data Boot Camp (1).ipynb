# %%
import pandas

# %%
# !pip install pysus
# Out:
# Requirement already satisfied: pysus in /opt/conda/lib/python3.6/site-packages
# Requirement already satisfied: dbfread in /opt/conda/lib/python3.6/site-packages (from pysus)
# Requirement already satisfied: requests in /opt/conda/lib/python3.6/site-packages (from pysus)
# Requirement already satisfied: cffi>=1.0.0 in /opt/conda/lib/python3.6/site-packages (from pysus)
# Requirement already satisfied: geocoder in /opt/conda/lib/python3.6/site-packages (from pysus)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.6/site-packages (from pysus)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests->pysus)
# Requirement already satisfied: idna<2.7,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests->pysus)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests->pysus)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests->pysus)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.6/site-packages (from cffi>=1.0.0->pysus)
# Requirement already satisfied: ratelim in /opt/conda/lib/python3.6/site-packages (from geocoder->pysus)
# Requirement already satisfied: future in /opt/conda/lib/python3.6/site-packages (from geocoder->pysus)
# Requirement already satisfied: click in /opt/conda/lib/python3.6/site-packages (from geocoder->pysus)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from geocoder->pysus)
# Requirement already satisfied: pytz>=2011k in /opt/conda/lib/python3.6/site-packages (from pandas->pysus)
# Requirement already satisfied: numpy>=1.9.0 in /opt/conda/lib/python3.6/site-packages (from pandas->pysus)
# Requirement already satisfied: python-dateutil>=2 in /opt/conda/lib/python3.6/site-packages (from pandas->pysus)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.6/site-packages (from ratelim->geocoder->pysus)

# %%
from pysus.utilities.readdbc import read_dbc

df = read_dbc("DNRJ2015.dbc", encoding = 'iso-8859-1')
# Out:
# True

# %%
df.head()
# Out:
#    NUMERODN        CODINST ORIGEM NUMERODV PREFIXODN CODESTAB CODMUNNASC  \
# 0  13660401  MRJ3303900001      1                     2275554     330390
# 1  53258484  RRJ3304550000      1        0        30  2273101     330412
# 2  53258485  RRJ3304550000      1        8        30  2273101     330412
# 3  53302375  RRJ3304550000      1        2        30  2290073     330140
# 4  53302376  RRJ3304550000      1        0        30  2290073     330140
#
#   LOCNASC IDADEMAE ESTCIVMAE   ...    TPNASCASSI TPFUNCRESP TPDOCRESP  \
# 0       2       26         1   ...
# 1       1       27         1   ...
# 2       1       28         1   ...
# 3       1       19         1   ...
# 4       1       18         1   ...
#
#   DTDECLARAC ESCMAEAGR1 TPROBSON STDNEPIDEM STDNNOVA CODPAISRES PARIDADE
# 0                             11          0        0          1        0
# 1                             11          0        0          1        1
# 2                             11          0        0          1        0
# 3                             11          0        0          1        0
# 4                             11          0        0          1        1
#
# [5 rows x 63 columns]

# %%
df.isnull().sum()
# Out:
# NUMERODN      0
# CODINST       0
# ORIGEM        0
# NUMERODV      0
# PREFIXODN     0
# CODESTAB      0
# CODMUNNASC    0
# LOCNASC       0
# IDADEMAE      0
# ESTCIVMAE     0
# ESCMAE        0
# CODOCUPMAE    0
# QTDFILVIVO    0
# QTDFILMORT    0
# CODMUNRES     0
# GESTACAO      0
# GRAVIDEZ      0
# PARTO         0
# CONSULTAS     0
# DTNASC        0
# HORANASC      0
# SEXO          0
# APGAR1        0
# APGAR5        0
# RACACOR       0
# PESO          0
# IDANOMAL      0
# DTCADASTRO    0
# CODANOMAL     0
# NUMEROLOTE    0
#              ..
# DTRECORIG     0
# NATURALMAE    0
# CODMUNNATU    0
# CODUFNATU     0
# ESCMAE2010    0
# SERIESCMAE    0
# DTNASCMAE     0
# RACACORMAE    0
# QTDGESTANT    0
# QTDPARTNOR    0
# QTDPARTCES    0
# IDADEPAI      0
# DTULTMENST    0
# SEMAGESTAC    0
# TPMETESTIM    0
# CONSPRENAT    0
# MESPRENAT     0
# TPAPRESENT    0
# STTRABPART    0
# STCESPARTO    0
# TPNASCASSI    0
# TPFUNCRESP    0
# TPDOCRESP     0
# DTDECLARAC    0
# ESCMAEAGR1    0
# TPROBSON      0
# STDNEPIDEM    0
# STDNNOVA      0
# CODPAISRES    0
# PARIDADE      0
# Length: 63, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236960 entries, 0 to 236959
# Data columns (total 63 columns):
# NUMERODN      236960 non-null object
# CODINST       236960 non-null object
# ORIGEM        236960 non-null object
# NUMERODV      236960 non-null object
# PREFIXODN     236960 non-null object
# CODESTAB      236960 non-null object
# CODMUNNASC    236960 non-null object
# LOCNASC       236960 non-null object
# IDADEMAE      236960 non-null object
# ESTCIVMAE     236960 non-null object
# ESCMAE        236960 non-null object
# CODOCUPMAE    236960 non-null object
# QTDFILVIVO    236960 non-null object
# QTDFILMORT    236960 non-null object
# CODMUNRES     236960 non-null object
# GESTACAO      236960 non-null object
# GRAVIDEZ      236960 non-null object
# PARTO         236960 non-null object
# CONSULTAS     236960 non-null object
# DTNASC        236960 non-null object
# HORANASC      236960 non-null object
# SEXO          236960 non-null object
# APGAR1        236960 non-null object
# APGAR5        236960 non-null object
# RACACOR       236960 non-null object
# PESO          236960 non-null object
# IDANOMAL      236960 non-null object
# DTCADASTRO    236960 non-null object
# CODANOMAL     236960 non-null object
# NUMEROLOTE    236960 non-null object
# VERSAOSIST    236960 non-null object
# DTRECEBIM     236960 non-null object
# DIFDATA       236960 non-null object
# DTRECORIG     236960 non-null object
# NATURALMAE    236960 non-null object
# CODMUNNATU    236960 non-null object
# CODUFNATU     236960 non-null object
# ESCMAE2010    236960 non-null object
# SERIESCMAE    236960 non-null object
# DTNASCMAE     236960 non-null object
# RACACORMAE    236960 non-null object
# QTDGESTANT    236960 non-null object
# QTDPARTNOR    236960 non-null object
# QTDPARTCES    236960 non-null object
# IDADEPAI      236960 non-null object
# DTULTMENST    236960 non-null object
# SEMAGESTAC    236960 non-null object
# TPMETESTIM    236960 non-null object
# CONSPRENAT    236960 non-null object
# MESPRENAT     236960 non-null object
# TPAPRESENT    236960 non-null object
# STTRABPART    236960 non-null object
# STCESPARTO    236960 non-null object
# TPNASCASSI    236960 non-null object
# TPFUNCRESP    236960 non-null object
# TPDOCRESP     236960 non-null object
# DTDECLARAC    236960 non-null object
# ESCMAEAGR1    236960 non-null object
# TPROBSON      236960 non-null object
# STDNEPIDEM    236960 non-null object
# STDNNOVA      236960 non-null object
# CODPAISRES    236960 non-null object
# PARIDADE      236960 non-null object
# dtypes: object(63)
# memory usage: 113.9+ MB

# %%
df.columns
# Out:
# Index(['NUMERODN', 'CODINST', 'ORIGEM', 'NUMERODV', 'PREFIXODN', 'CODESTAB',
#        'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE', 'ESCMAE',
#        'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES', 'GESTACAO',
#        'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC', 'SEXO',
#        'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIG', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'TPROBSON', 'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'PARIDADE'],
#       dtype='object')

# %%
df_2 = df[["IDADEMAE","ESTCIVMAE","ESCMAE","CODOCUPMAE","QTDFILVIVO"
           ,"QTDFILMORT","GESTACAO","GRAVIDEZ","PARTO","CODMUNRES","CODMUNNASC","SEXO"
           ,"CONSULTAS","DTNASC","RACACOR","IDANOMAL","ESCMAE","IDADEPAI"]]

# %%
df_2[df_2 == ''].count()
# Out:
# IDADEMAE           0
# ESTCIVMAE        960
# ESCMAE          1269
# CODOCUPMAE     32771
# QTDFILVIVO      5921
# QTDFILMORT      9168
# GESTACAO        5259
# GRAVIDEZ         228
# PARTO            205
# CODMUNRES          0
# CODMUNNASC         0
# SEXO               0
# CONSULTAS          2
# DTNASC             0
# RACACOR         6842
# IDANOMAL         905
# ESCMAE          1269
# IDADEPAI      108055
# dtype: int64

# %%
def to_int(lista):
    if lista == '':
        return -1
    else:
        return int(lista)

# %%
def ajuste_estado(lista):
    if lista != '':
        if int(lista) == 1:
            return 'solteira'
        elif int(lista) == 2:
            return 'casada'
        elif int(lista) == 3:
            return 'viuva'
        elif int(lista) == 4:
            return 'divorciada'
        else:
            return 'ignorado'
    else:
        return 'NaN'
        
estado_civil_mae = df_2["ESTCIVMAE"].apply(ajuste_estado)

# %%
estado_civil_mae.head()
# Out:
# 0    solteira
# 1    solteira
# 2    solteira
# 3    solteira
# 4    solteira
# Name: ESTCIVMAE, dtype: object

# %%
df_2["estado_civil_mae"] = estado_civil_mae
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2.head()
# Out:
#   IDADEMAE ESTCIVMAE ESCMAE CODOCUPMAE QTDFILVIVO QTDFILMORT GESTACAO  \
# 0       26         1      2     763305         99         99        1
# 1       27         1      3                    04         00        5
# 2       28         1      4     513435         00         00        9
# 3       19         1      3                    00         00        5
# 4       18         1      4                    02         00        9
#
#   GRAVIDEZ PARTO CODMUNRES CODMUNNASC SEXO CONSULTAS    DTNASC RACACOR  \
# 0        1     1    330390     330390    1         1  04042015       4
# 1        1     1    330412     330412    2         1  18052015       4
# 2        1     1    330412     330412    1         1  14102015       2
# 3        1     1    330140     330140    2         3  23062015       1
# 4        1     1    330140     330140    1         1  07102015       4
#
#   IDANOMAL ESCMAE IDADEPAI estado_civil_mae
# 0        2      2                  solteira
# 1        2      3                  solteira
# 2        2      4                  solteira
# 3        2      3                  solteira
# 4        2      4                  solteira

# %%
cols_int = ["IDADEMAE","QTDFILVIVO"
           ,"QTDFILMORT","GRAVIDEZ","IDADEPAI"]

for i in cols_int:
    df_2[i] = df_2[i].apply(to_int)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236960 entries, 0 to 236959
# Data columns (total 19 columns):
# IDADEMAE            236960 non-null int64
# ESTCIVMAE           236960 non-null object
# ESCMAE              236960 non-null object
# CODOCUPMAE          236960 non-null object
# QTDFILVIVO          236960 non-null int64
# QTDFILMORT          236960 non-null int64
# GESTACAO            236960 non-null object
# GRAVIDEZ            236960 non-null int64
# PARTO               236960 non-null object
# CODMUNRES           236960 non-null object
# CODMUNNASC          236960 non-null object
# SEXO                236960 non-null object
# CONSULTAS           236960 non-null object
# DTNASC              236960 non-null object
# RACACOR             236960 non-null object
# IDANOMAL            236960 non-null object
# ESCMAE              236960 non-null object
# IDADEPAI            236960 non-null int64
# estado_civil_mae    236960 non-null object
# dtypes: int64(5), object(14)
# memory usage: 34.3+ MB

# %%
def ajuste_escolaridade(lista):
    if lista != '':
        if int(lista) == 1:
            return 0.0
        elif int(lista) == 2:
            return 2.0
        elif int(lista) == 3:
            return 5.5
        elif int(lista) == 4:
            return 9.5
        elif int(lista) == 5:
            return 12.0
        else:
            return -1.0
    else:
        return -1.0

# %%
df_2 = df_2.drop("ESCMAE",axis=1)

# %%
df_2["media_escolaridade_mae"] = df.ESCMAE.apply(ajuste_escolaridade)

# %%
df_2 = df_2.drop("CODOCUPMAE",axis=1)

# %%
def ajuste_gestacao(lista):
    if lista != '':
        if int(lista) == 1:
            return 22.0
        elif int(lista) == 2:
            return 24.5
        elif int(lista) == 3:
            return 29.5
        elif int(lista) == 4:
            return 34.0
        elif int(lista) == 5:
            return 39
        elif int(lista) == 6:
            return 42
        else:
            return -1.0
    else:
        return -1.0
    
df_2["media_gestacao"] = df.GRAVIDEZ.apply(ajuste_gestacao)

# %%
df_2.head()
# Out:
#    IDADEMAE ESTCIVMAE  QTDFILVIVO  QTDFILMORT GESTACAO  GRAVIDEZ PARTO  \
# 0        26         1          99          99        1         1     1
# 1        27         1           4           0        5         1     1
# 2        28         1           0           0        9         1     1
# 3        19         1           0           0        5         1     1
# 4        18         1           2           0        9         1     1
#
#   CODMUNRES CODMUNNASC SEXO CONSULTAS    DTNASC RACACOR IDANOMAL  IDADEPAI  \
# 0    330390     330390    1         1  04042015       4        2        -1
# 1    330412     330412    2         1  18052015       4        2        -1
# 2    330412     330412    1         1  14102015       2        2        -1
# 3    330140     330140    2         3  23062015       1        2        -1
# 4    330140     330140    1         1  07102015       4        2        -1
#
#   estado_civil_mae  media_escolaridade_mae  media_gestacao
# 0         solteira                     2.0            22.0
# 1         solteira                     5.5            22.0
# 2         solteira                     9.5            22.0
# 3         solteira                     5.5            22.0
# 4         solteira                     9.5            22.0

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236960 entries, 0 to 236959
# Data columns (total 18 columns):
# IDADEMAE                  236960 non-null int64
# ESTCIVMAE                 236960 non-null object
# QTDFILVIVO                236960 non-null int64
# QTDFILMORT                236960 non-null int64
# GESTACAO                  236960 non-null object
# GRAVIDEZ                  236960 non-null int64
# PARTO                     236960 non-null object
# CODMUNRES                 236960 non-null object
# CODMUNNASC                236960 non-null object
# SEXO                      236960 non-null object
# CONSULTAS                 236960 non-null object
# DTNASC                    236960 non-null object
# RACACOR                   236960 non-null object
# IDANOMAL                  236960 non-null object
# IDADEPAI                  236960 non-null int64
# estado_civil_mae          236960 non-null object
# media_escolaridade_mae    236960 non-null float64
# media_gestacao            236960 non-null float64
# dtypes: float64(2), int64(5), object(11)
# memory usage: 32.5+ MB

# %%
def ajuste_parto(lista):
    if lista != '':
        if int(lista) == 1:
            return 0
        elif int(lista) == 2:
            return 1
        else:
            return -1.0
    else:
        return -1.0
df_2["parto_boolean"] = df.PARTO.apply(ajuste_parto)

# %%
df_2.head()
# Out:
#    IDADEMAE ESTCIVMAE  QTDFILVIVO  QTDFILMORT GESTACAO  GRAVIDEZ PARTO  \
# 0        26         1          99          99        1         1     1
# 1        27         1           4           0        5         1     1
# 2        28         1           0           0        9         1     1
# 3        19         1           0           0        5         1     1
# 4        18         1           2           0        9         1     1
#
#   CODMUNRES CODMUNNASC SEXO CONSULTAS    DTNASC RACACOR IDANOMAL  IDADEPAI  \
# 0    330390     330390    1         1  04042015       4        2        -1
# 1    330412     330412    2         1  18052015       4        2        -1
# 2    330412     330412    1         1  14102015       2        2        -1
# 3    330140     330140    2         3  23062015       1        2        -1
# 4    330140     330140    1         1  07102015       4        2        -1
#
#   estado_civil_mae  media_escolaridade_mae  media_gestacao  parto_boolean
# 0         solteira                     2.0            22.0            0.0
# 1         solteira                     5.5            22.0            0.0
# 2         solteira                     9.5            22.0            0.0
# 3         solteira                     5.5            22.0            0.0
# 4         solteira                     9.5            22.0            0.0

# %%
df_2 = df_2.drop("PARTO",axis=1)

# %%
def ajuste_sexo_1(lista):
    if lista != '':
        if int(lista) == 1:
            return 0
        elif int(lista) == 2:
            return 1
        else:
            return -1.0
    else:
        return -1.0
df_2["sexo_boolean"] = df.SEXO.apply(ajuste_sexo_1)

# %%
def ajuste_sexo_2(lista):
    if lista != '':
        if int(lista) == 1:
            return 'masculino'
        elif int(lista) == 2:
            return 'feminino'
        else:
            return 'NaN'
    else:
        return 'NaN'
df_2["sexo"] = df.SEXO.apply(ajuste_sexo_2)

# %%
df_2 = df_2.drop("SEXO",axis=1)

# %%
df_2.head()
# Out:
#    IDADEMAE ESTCIVMAE  QTDFILVIVO  QTDFILMORT GESTACAO  GRAVIDEZ CODMUNRES  \
# 0        26         1          99          99        1         1    330390
# 1        27         1           4           0        5         1    330412
# 2        28         1           0           0        9         1    330412
# 3        19         1           0           0        5         1    330140
# 4        18         1           2           0        9         1    330140
#
#   CODMUNNASC CONSULTAS    DTNASC RACACOR IDANOMAL  IDADEPAI estado_civil_mae  \
# 0     330390         1  04042015       4        2        -1         solteira
# 1     330412         1  18052015       4        2        -1         solteira
# 2     330412         1  14102015       2        2        -1         solteira
# 3     330140         3  23062015       1        2        -1         solteira
# 4     330140         1  07102015       4        2        -1         solteira
#
#    media_escolaridade_mae  media_gestacao  parto_boolean  sexo_boolean  \
# 0                     2.0            22.0            0.0           0.0
# 1                     5.5            22.0            0.0           1.0
# 2                     9.5            22.0            0.0           0.0
# 3                     5.5            22.0            0.0           1.0
# 4                     9.5            22.0            0.0           0.0
#
#         sexo
# 0  masculino
# 1   feminino
# 2  masculino
# 3   feminino
# 4  masculino

# %%
def ajuste_parto_2(lista):
    if lista != '':
        if int(lista) == 1:
            return 'vaginal'
        elif int(lista) == 2:
            return 'cesareo'
        else:
            return 'NaN'
    else:
        return 'NaN'
df_2["parto"] = df.PARTO.apply(ajuste_parto_2)

# %%
df_2.head()
# Out:
#    IDADEMAE ESTCIVMAE  QTDFILVIVO  QTDFILMORT GESTACAO  GRAVIDEZ CODMUNRES  \
# 0        26         1          99          99        1         1    330390
# 1        27         1           4           0        5         1    330412
# 2        28         1           0           0        9         1    330412
# 3        19         1           0           0        5         1    330140
# 4        18         1           2           0        9         1    330140
#
#   CODMUNNASC CONSULTAS    DTNASC RACACOR IDANOMAL  IDADEPAI estado_civil_mae  \
# 0     330390         1  04042015       4        2        -1         solteira
# 1     330412         1  18052015       4        2        -1         solteira
# 2     330412         1  14102015       2        2        -1         solteira
# 3     330140         3  23062015       1        2        -1         solteira
# 4     330140         1  07102015       4        2        -1         solteira
#
#    media_escolaridade_mae  media_gestacao  parto_boolean  sexo_boolean  \
# 0                     2.0            22.0            0.0           0.0
# 1                     5.5            22.0            0.0           1.0
# 2                     9.5            22.0            0.0           0.0
# 3                     5.5            22.0            0.0           1.0
# 4                     9.5            22.0            0.0           0.0
#
#         sexo    parto
# 0  masculino  vaginal
# 1   feminino  vaginal
# 2  masculino  vaginal
# 3   feminino  vaginal
# 4  masculino  vaginal

# %%
def ajuste_consultas(lista):
    if lista != '':
        if int(lista) == 1:
            return 0
        elif int(lista) == 2:
            return 2
        elif int(lista) == 3:
            return 5
        elif int(lista) == 4:
            return 7
        else:
            return -1.0
    else:
        return -1.0
    
df_2["media_consultas"] = df.CONSULTAS.apply(ajuste_consultas)

# %%
df_2.head()
# Out:
#    IDADEMAE ESTCIVMAE  QTDFILVIVO  QTDFILMORT GESTACAO  GRAVIDEZ CODMUNRES  \
# 0        26         1          99          99        1         1    330390
# 1        27         1           4           0        5         1    330412
# 2        28         1           0           0        9         1    330412
# 3        19         1           0           0        5         1    330140
# 4        18         1           2           0        9         1    330140
#
#   CODMUNNASC CONSULTAS    DTNASC       ...       IDANOMAL IDADEPAI  \
# 0     330390         1  04042015       ...              2       -1
# 1     330412         1  18052015       ...              2       -1
# 2     330412         1  14102015       ...              2       -1
# 3     330140         3  23062015       ...              2       -1
# 4     330140         1  07102015       ...              2       -1
#
#    estado_civil_mae media_escolaridade_mae  media_gestacao  parto_boolean  \
# 0          solteira                    2.0            22.0            0.0
# 1          solteira                    5.5            22.0            0.0
# 2          solteira                    9.5            22.0            0.0
# 3          solteira                    5.5            22.0            0.0
# 4          solteira                    9.5            22.0            0.0
#
#    sexo_boolean       sexo    parto media_consultas
# 0           0.0  masculino  vaginal             0.0
# 1           1.0   feminino  vaginal             0.0
# 2           0.0  masculino  vaginal             0.0
# 3           1.0   feminino  vaginal             5.0
# 4           0.0  masculino  vaginal             0.0
#
# [5 rows x 21 columns]

# %%
def ajuste_raca(lista):
    if lista != '':
        if int(lista) == 1:
            return 'branca'
        elif int(lista) == 2:
            return 'preta'
        elif int(lista) == 3:
            return 'amarela'
        elif int(lista) == 4:
            return 'parda'
        elif int(lista) == 5:
            return 'indigena'
        else:
            return 'NaN'
    else:

        return 'NaN'
df_2["raca_mae"] = df_2["RACACOR"].apply(ajuste_raca)
df_2 = df_2.drop("RACACOR",axis=1)

# %%
df_2.head()
# Out:
#    IDADEMAE ESTCIVMAE  QTDFILVIVO  QTDFILMORT GESTACAO  GRAVIDEZ CODMUNRES  \
# 0        26         1          99          99        1         1    330390
# 1        27         1           4           0        5         1    330412
# 2        28         1           0           0        9         1    330412
# 3        19         1           0           0        5         1    330140
# 4        18         1           2           0        9         1    330140
#
#   CODMUNNASC CONSULTAS    DTNASC    ...    IDADEPAI  estado_civil_mae  \
# 0     330390         1  04042015    ...          -1          solteira
# 1     330412         1  18052015    ...          -1          solteira
# 2     330412         1  14102015    ...          -1          solteira
# 3     330140         3  23062015    ...          -1          solteira
# 4     330140         1  07102015    ...          -1          solteira
#
#   media_escolaridade_mae  media_gestacao  parto_boolean  sexo_boolean  \
# 0                    2.0            22.0            0.0           0.0
# 1                    5.5            22.0            0.0           1.0
# 2                    9.5            22.0            0.0           0.0
# 3                    5.5            22.0            0.0           1.0
# 4                    9.5            22.0            0.0           0.0
#
#         sexo    parto media_consultas  raca_mae
# 0  masculino  vaginal             0.0     parda
# 1   feminino  vaginal             0.0     parda
# 2  masculino  vaginal             0.0     preta
# 3   feminino  vaginal             5.0    branca
# 4  masculino  vaginal             0.0     parda
#
# [5 rows x 21 columns]

# %%
def ajuste_anomalia(lista):
    if lista != '':
        if int(lista) == 1:
            return 1
        elif int(lista) == 2:
            return 0
        else:
            return -1
    else:

        return -1

df_2["anomalia_boolean"] = df.IDANOMAL.apply(ajuste_anomalia)

# %%
df_2.head()
# Out:
#    IDADEMAE ESTCIVMAE  QTDFILVIVO  QTDFILMORT GESTACAO  GRAVIDEZ CODMUNRES  \
# 0        26         1          99          99        1         1    330390
# 1        27         1           4           0        5         1    330412
# 2        28         1           0           0        9         1    330412
# 3        19         1           0           0        5         1    330140
# 4        18         1           2           0        9         1    330140
#
#   CODMUNNASC CONSULTAS    DTNASC        ...        estado_civil_mae  \
# 0     330390         1  04042015        ...                solteira
# 1     330412         1  18052015        ...                solteira
# 2     330412         1  14102015        ...                solteira
# 3     330140         3  23062015        ...                solteira
# 4     330140         1  07102015        ...                solteira
#
#    media_escolaridade_mae media_gestacao  parto_boolean  sexo_boolean  \
# 0                     2.0           22.0            0.0           0.0
# 1                     5.5           22.0            0.0           1.0
# 2                     9.5           22.0            0.0           0.0
# 3                     5.5           22.0            0.0           1.0
# 4                     9.5           22.0            0.0           0.0
#
#         sexo    parto media_consultas raca_mae  anomalia_boolean
# 0  masculino  vaginal             0.0    parda                 0
# 1   feminino  vaginal             0.0    parda                 0
# 2  masculino  vaginal             0.0    preta                 0
# 3   feminino  vaginal             5.0   branca                 0
# 4  masculino  vaginal             0.0    parda                 0
#
# [5 rows x 22 columns]

# %%
df_2 = df_2.drop("ESTCIVMAE",axis=1)

# %%
df_2.shape
# Out:
# (236960, 21)

# %%
df_2["data_nasc"] = pandas.to_datetime(df_2["DTNASC"],format="%d%m%Y")

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236960 entries, 0 to 236959
# Data columns (total 22 columns):
# IDADEMAE                  236960 non-null int64
# QTDFILVIVO                236960 non-null int64
# QTDFILMORT                236960 non-null int64
# GESTACAO                  236960 non-null object
# GRAVIDEZ                  236960 non-null int64
# CODMUNRES                 236960 non-null object
# CODMUNNASC                236960 non-null object
# CONSULTAS                 236960 non-null object
# DTNASC                    236960 non-null object
# IDANOMAL                  236960 non-null object
# IDADEPAI                  236960 non-null int64
# estado_civil_mae          236960 non-null object
# media_escolaridade_mae    236960 non-null float64
# media_gestacao            236960 non-null float64
# parto_boolean             236960 non-null float64
# sexo_boolean              236960 non-null float64
# sexo                      236960 non-null object
# parto                     236960 non-null object
# media_consultas           236960 non-null float64
# raca_mae                  236960 non-null object
# anomalia_boolean          236960 non-null int64
# data_nasc                 236960 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), int64(6), object(10)
# memory usage: 39.8+ MB

# %%
df_2 = df_2.drop("DTNASC",axis=1)

# %%
df_2.head()
# Out:
#    IDADEMAE  QTDFILVIVO  QTDFILMORT GESTACAO  GRAVIDEZ CODMUNRES CODMUNNASC  \
# 0        26          99          99        1         1    330390     330390
# 1        27           4           0        5         1    330412     330412
# 2        28           0           0        9         1    330412     330412
# 3        19           0           0        5         1    330140     330140
# 4        18           2           0        9         1    330140     330140
#
#   CONSULTAS IDANOMAL  IDADEPAI    ...     media_escolaridade_mae  \
# 0         1        2        -1    ...                        2.0
# 1         1        2        -1    ...                        5.5
# 2         1        2        -1    ...                        9.5
# 3         3        2        -1    ...                        5.5
# 4         1        2        -1    ...                        9.5
#
#    media_gestacao  parto_boolean  sexo_boolean       sexo    parto  \
# 0            22.0            0.0           0.0  masculino  vaginal
# 1            22.0            0.0           1.0   feminino  vaginal
# 2            22.0            0.0           0.0  masculino  vaginal
# 3            22.0            0.0           1.0   feminino  vaginal
# 4            22.0            0.0           0.0  masculino  vaginal
#
#   media_consultas  raca_mae anomalia_boolean  data_nasc
# 0             0.0     parda                0 2015-04-04
# 1             0.0     parda                0 2015-05-18
# 2             0.0     preta                0 2015-10-14
# 3             5.0    branca                0 2015-06-23
# 4             0.0     parda                0 2015-10-07
#
# [5 rows x 21 columns]

# %%
df_2[df_2 == ''].count()
# Out:
# IDADEMAE                     0
# QTDFILVIVO                   0
# QTDFILMORT                   0
# GESTACAO                  5259
# GRAVIDEZ                     0
# CODMUNRES                    0
# CODMUNNASC                   0
# CONSULTAS                    2
# IDANOMAL                   905
# IDADEPAI                     0
# estado_civil_mae             0
# media_escolaridade_mae       0
# media_gestacao               0
# parto_boolean                0
# sexo_boolean                 0
# sexo                         0
# parto                        0
# media_consultas              0
# raca_mae                     0
# anomalia_boolean             0
# data_nasc                    0
# dtype: int64

# %%
df_2 = df_2.drop("GESTACAO",axis=1)

# %%
df_2.head()
# Out:
#    IDADEMAE  QTDFILVIVO  QTDFILMORT  GRAVIDEZ CODMUNRES CODMUNNASC CONSULTAS  \
# 0        26          99          99         1    330390     330390         1
# 1        27           4           0         1    330412     330412         1
# 2        28           0           0         1    330412     330412         1
# 3        19           0           0         1    330140     330140         3
# 4        18           2           0         1    330140     330140         1
#
#   IDANOMAL  IDADEPAI estado_civil_mae  media_escolaridade_mae  media_gestacao  \
# 0        2        -1         solteira                     2.0            22.0
# 1        2        -1         solteira                     5.5            22.0
# 2        2        -1         solteira                     9.5            22.0
# 3        2        -1         solteira                     5.5            22.0
# 4        2        -1         solteira                     9.5            22.0
#
#    parto_boolean  sexo_boolean       sexo    parto  media_consultas raca_mae  \
# 0            0.0           0.0  masculino  vaginal              0.0    parda
# 1            0.0           1.0   feminino  vaginal              0.0    parda
# 2            0.0           0.0  masculino  vaginal              0.0    preta
# 3            0.0           1.0   feminino  vaginal              5.0   branca
# 4            0.0           0.0  masculino  vaginal              0.0    parda
#
#    anomalia_boolean  data_nasc
# 0                 0 2015-04-04
# 1                 0 2015-05-18
# 2                 0 2015-10-14
# 3                 0 2015-06-23
# 4                 0 2015-10-07

# %%
df_2.head()
# Out:
#    IDADEMAE  QTDFILVIVO  QTDFILMORT  GRAVIDEZ CODMUNRES CODMUNNASC CONSULTAS  \
# 0        26          99          99         1    330390     330390         1
# 1        27           4           0         1    330412     330412         1
# 2        28           0           0         1    330412     330412         1
# 3        19           0           0         1    330140     330140         3
# 4        18           2           0         1    330140     330140         1
#
#   IDANOMAL  IDADEPAI estado_civil_mae  media_escolaridade_mae  media_gestacao  \
# 0        2        -1         solteira                     2.0            22.0
# 1        2        -1         solteira                     5.5            22.0
# 2        2        -1         solteira                     9.5            22.0
# 3        2        -1         solteira                     5.5            22.0
# 4        2        -1         solteira                     9.5            22.0
#
#    parto_boolean  sexo_boolean       sexo    parto  media_consultas raca_mae  \
# 0            0.0           0.0  masculino  vaginal              0.0    parda
# 1            0.0           1.0   feminino  vaginal              0.0    parda
# 2            0.0           0.0  masculino  vaginal              0.0    preta
# 3            0.0           1.0   feminino  vaginal              5.0   branca
# 4            0.0           0.0  masculino  vaginal              0.0    parda
#
#    anomalia_boolean  data_nasc
# 0                 0 2015-04-04
# 1                 0 2015-05-18
# 2                 0 2015-10-14
# 3                 0 2015-06-23
# 4                 0 2015-10-07

# %%
from scipy import stats
import seaborn as sbn
import numpy as np
# %matplotlib inline

# %%
df_2[df_2 == -1].count()
# Out:
# IDADEMAE                       0
# QTDFILVIVO                  5921
# QTDFILMORT                  9168
# GRAVIDEZ                     228
# CODMUNRES                      0
# CODMUNNASC                     0
# CONSULTAS                      0
# IDANOMAL                       0
# IDADEPAI                  108055
# estado_civil_mae               0
# media_escolaridade_mae      2644
# media_gestacao               236
# parto_boolean                212
# sexo_boolean                  28
# sexo                           0
# parto                          0
# media_consultas             3274
# raca_mae                       0
# anomalia_boolean            6368
# data_nasc                      0
# dtype: int64

# %%
df_final = df_2.replace(-1, np.nan)

# %%
df_final[df_final == -1].count()
# Out:
# IDADEMAE                  0
# QTDFILVIVO                0
# QTDFILMORT                0
# GRAVIDEZ                  0
# CODMUNRES                 0
# CODMUNNASC                0
# CONSULTAS                 0
# IDANOMAL                  0
# IDADEPAI                  0
# estado_civil_mae          0
# media_escolaridade_mae    0
# media_gestacao            0
# parto_boolean             0
# sexo_boolean              0
# sexo                      0
# parto                     0
# media_consultas           0
# raca_mae                  0
# anomalia_boolean          0
# data_nasc                 0
# dtype: int64

# %%
df_final = df_final.replace('NaN', np.nan)
df_final = df_final.replace('', np.nan)

# %%
df_final.isnull().sum()
# Out:
# IDADEMAE                       0
# QTDFILVIVO                  5921
# QTDFILMORT                  9168
# GRAVIDEZ                     228
# CODMUNRES                      0
# CODMUNNASC                     0
# CONSULTAS                      2
# IDANOMAL                     905
# IDADEPAI                  108055
# estado_civil_mae             960
# media_escolaridade_mae      2644
# media_gestacao               236
# parto_boolean                212
# sexo_boolean                  28
# sexo                          28
# parto                        212
# media_consultas             3274
# raca_mae                    6842
# anomalia_boolean            6368
# data_nasc                      0
# dtype: int64

# %%
sbn.lmplot(x="IDADEMAE",y="IDADEPAI",hue="anomalia_boolean",data=df_final[df_final.notnull()],fit_reg=False)

# %%
df_final.notnull().sum()
# Out:
# IDADEMAE                  236960
# QTDFILVIVO                231039
# QTDFILMORT                227792
# GRAVIDEZ                  236732
# CODMUNRES                 236960
# CODMUNNASC                236960
# CONSULTAS                 236958
# IDANOMAL                  236055
# IDADEPAI                  128905
# estado_civil_mae          236000
# media_escolaridade_mae    234316
# media_gestacao            236724
# parto_boolean             236748
# sexo_boolean              236932
# sexo                      236932
# parto                     236748
# media_consultas           233686
# raca_mae                  230118
# anomalia_boolean          230592
# data_nasc                 236960
# dtype: int64

# %%
def dif_idades(dataframe):
    if (dataframe["IDADEPAI"]):
        return dataframe["IDADEPAI"] - dataframe["IDADEMAE"]
    else:
        return np.nan
    
    
df_final["diferenca_idade_pais"] = df_final.apply(dif_idades,axis=1)

# %%
df_final.head()
# Out:
#    IDADEMAE  QTDFILVIVO  QTDFILMORT  GRAVIDEZ CODMUNRES CODMUNNASC CONSULTAS  \
# 0        26        99.0        99.0       1.0    330390     330390         1
# 1        27         4.0         0.0       1.0    330412     330412         1
# 2        28         0.0         0.0       1.0    330412     330412         1
# 3        19         0.0         0.0       1.0    330140     330140         3
# 4        18         2.0         0.0       1.0    330140     330140         1
#
#   IDANOMAL  IDADEPAI estado_civil_mae         ...           media_gestacao  \
# 0        2       NaN         solteira         ...                     22.0
# 1        2       NaN         solteira         ...                     22.0
# 2        2       NaN         solteira         ...                     22.0
# 3        2       NaN         solteira         ...                     22.0
# 4        2       NaN         solteira         ...                     22.0
#
#    parto_boolean  sexo_boolean       sexo    parto media_consultas  raca_mae  \
# 0            0.0           0.0  masculino  vaginal             0.0     parda
# 1            0.0           1.0   feminino  vaginal             0.0     parda
# 2            0.0           0.0  masculino  vaginal             0.0     preta
# 3            0.0           1.0   feminino  vaginal             5.0    branca
# 4            0.0           0.0  masculino  vaginal             0.0     parda
#
#   anomalia_boolean  data_nasc diferenca_idade_pais
# 0              0.0 2015-04-04                  NaN
# 1              0.0 2015-05-18                  NaN
# 2              0.0 2015-10-14                  NaN
# 3              0.0 2015-06-23                  NaN
# 4              0.0 2015-10-07                  NaN
#
# [5 rows x 21 columns]

# %%
sbn.countplot(df_final.diferenca_idade_pais)

# %%
df_final.diferenca_idade_pais.mode()
# Out:
# 0    2.0
# dtype: float64

# %%
df_final.diferenca_idade_pais.mean()
# Out:
# 3.4084325666188278

# %%
df_final.diferenca_idade_pais.describe()
# Out:
# count    128905.000000
# mean          3.408433
# std           6.064358
# min         -30.000000
# 25%           0.000000
# 50%           3.000000
# 75%           6.000000
# max          78.000000
# Name: diferenca_idade_pais, dtype: float64

# %%
df_final[df_final.diferenca_idade_pais==-30]
# Out:
#         IDADEMAE  QTDFILVIVO  QTDFILMORT  GRAVIDEZ CODMUNRES CODMUNNASC  \
# 204111        55         1.0         0.0       1.0    330420     330420
#
#        CONSULTAS IDANOMAL  IDADEPAI estado_civil_mae         ...           \
# 204111         4        2      25.0           casada         ...
#
#         media_gestacao  parto_boolean  sexo_boolean       sexo    parto  \
# 204111            22.0            0.0           0.0  masculino  vaginal
#
#        media_consultas  raca_mae anomalia_boolean  data_nasc  \
# 204111             7.0     parda              0.0 2015-09-11
#
#        diferenca_idade_pais
# 204111                -30.0
#
# [1 rows x 21 columns]

# %%
df_final.groupby("estado_civil_mae")["parto_boolean"].mean()
# Out:
# estado_civil_mae
# casada        0.791137
# divorciada    0.775017
# ignorado      0.673485
# solteira      0.509493
# viuva         0.706024
# Name: parto_boolean, dtype: float64

# %%
df_final.groupby("estado_civil_mae")["parto_boolean"].std()
# Out:
# estado_civil_mae
# casada        0.406499
# divorciada    0.417641
# ignorado      0.468960
# solteira      0.499912
# viuva         0.456131
# Name: parto_boolean, dtype: float64

# %%
stats.ttest_ind(df_final[df_final.estado_civil_mae=="casada"].parto_boolean
                ,df_final[df_final.estado_civil_mae=="divorciada"].parto_boolean,equal_var=False,nan_policy='omit')
# Out:
# Ttest_indResult(statistic=2.0798937302589802, pvalue=0.037613240892082622)

# %%
stats.ttest_ind(df_final[df_final.estado_civil_mae=="casada"].parto_boolean
                ,df_final[df_final.estado_civil_mae=="solteira"].parto_boolean,equal_var=False,nan_policy='omit')
# Out:
# Ttest_indResult(statistic=141.59492496783804, pvalue=0.0)

# %%
stats.ttest_ind(df_final[df_final.estado_civil_mae=="casada"].parto_boolean
                ,df_final[df_final.estado_civil_mae=="viuva"].parto_boolean,equal_var=False,nan_policy='omit')
# Out:
# Ttest_indResult(statistic=3.7926842722506908, pvalue=0.0001710105235586156)

# %%
stats.ttest_ind(df_final[df_final.estado_civil_mae=="solteira"].parto_boolean
                ,df_final[df_final.estado_civil_mae=="divorciada"].parto_boolean,equal_var=False,nan_policy='omit')
# Out:
# Ttest_indResult(statistic=-34.431425396743407, pvalue=3.1149520067740539e-221)

# %%
stats.ttest_ind(df_final[df_final.estado_civil_mae=="viuva"].parto_boolean
                ,df_final[df_final.estado_civil_mae=="divorciada"].parto_boolean,equal_var=False,nan_policy='omit')
# Out:
# Ttest_indResult(statistic=-2.9177240476306712, pvalue=0.0036802889069349636)

# %%
stats.ttest_ind(df_final[df_final.estado_civil_mae=="viuva"].parto_boolean
                ,df_final[df_final.estado_civil_mae=="solteira"].parto_boolean,equal_var=False,nan_policy='omit')
# Out:
# Ttest_indResult(statistic=8.7627786975027497, pvalue=4.857916557877147e-17)

# %%
sbn.countplot(df_final.data_nasc)

# %%
def count(data_frame):
    return 1

df_final['inutil'] = df_final.data_nasc.apply(count)

# %%
df_final.head()
# Out:
#    IDADEMAE  QTDFILVIVO  QTDFILMORT  GRAVIDEZ CODMUNRES CODMUNNASC CONSULTAS  \
# 0        26        99.0        99.0       1.0    330390     330390         1
# 1        27         4.0         0.0       1.0    330412     330412         1
# 2        28         0.0         0.0       1.0    330412     330412         1
# 3        19         0.0         0.0       1.0    330140     330140         3
# 4        18         2.0         0.0       1.0    330140     330140         1
#
#   IDANOMAL  IDADEPAI estado_civil_mae  ...    parto_boolean  sexo_boolean  \
# 0        2       NaN         solteira  ...              0.0           0.0
# 1        2       NaN         solteira  ...              0.0           1.0
# 2        2       NaN         solteira  ...              0.0           0.0
# 3        2       NaN         solteira  ...              0.0           1.0
# 4        2       NaN         solteira  ...              0.0           0.0
#
#         sexo    parto media_consultas raca_mae  anomalia_boolean  data_nasc  \
# 0  masculino  vaginal             0.0    parda               0.0 2015-04-04
# 1   feminino  vaginal             0.0    parda               0.0 2015-05-18
# 2  masculino  vaginal             0.0    preta               0.0 2015-10-14
# 3   feminino  vaginal             5.0   branca               0.0 2015-06-23
# 4  masculino  vaginal             0.0    parda               0.0 2015-10-07
#
#    diferenca_idade_pais inutil
# 0                   NaN      1
# 1                   NaN      1
# 2                   NaN      1
# 3                   NaN      1
# 4                   NaN      1
#
# [5 rows x 22 columns]

# %%
sbn.tsplot(data=df_final,value=df_final.inutil,time=df_final.data_nasc.dt.month)
# Out:
# /opt/conda/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-101-2694134f0c4b> in <module>()
# ----> 1 sbn.tsplot(data=df_final,value=df_final.inutil,time=df_final.data_nasc.dt.month)
#
# /opt/conda/lib/python3.6/site-packages/seaborn/timeseries.py in tsplot(data, time, unit, condition, value, err_style, ci, interpolate, color, estimator, n_boot, err_palette, err_kws, legend, ax, **kwargs)
#     294     for c, (cond, df_c) in enumerate(data.groupby(condition, sort=False)):
#     295
# --> 296         df_c = df_c.pivot(unit, time, value)
#     297         x = df_c.columns.values.astype(np.float)
#     298
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    4380         """
#    4381         from pandas.core.reshape.reshape import pivot
# -> 4382         return pivot(self, index=index, columns=columns, values=values)
#    4383
#    4384     _shared_docs['pivot_table'] = """
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/reshape/reshape.py in pivot(self, index, columns, values)
#     385         else:
#     386             index = self[index]
# --> 387         indexed = Series(self[values].values,
#     388                          index=MultiIndex.from_arrays([index, self[columns]]))
#     389         return indexed.unstack(columns)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2178             return self._take(indexer, axis=1, convert=True)
#    2179
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1267                 if mask.any():
#    1268                     raise KeyError('{mask} not in index'
# -> 1269                                    .format(mask=objarr[mask]))
#    1270
#    1271                 return _values_from_object(indexer)
#
# KeyError: '[1 1 1 ..., 1 1 1] not in index'
